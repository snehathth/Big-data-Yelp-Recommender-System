# %% [markdown]
# # Yelp Recommendation Engine
#
# Yelp releases their data for academic purposes and challenges the students community to come up with ideas that can help evolve the company. We are breaking the dataset into a small chunk and creating a recommendation system that will help the user choose the restuarant based on a few choices they have in a particular city.
#
# ## Exploratory Analysis
#
# ### For Business
#
# #### We need to come up with an accepted range of data as the downloaded yelp dataset contains 10,000,000 rows and we do not have the capacity to run analysis on these many rows.
#
# * Identify the right Category
# * Idenitfy the right City
# * Identify the relevant reviews
#
#
# **Step 1:** Importing Libraries for exploration

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We have decided that we want to recommend a restuarant to the end user. Hence the category will be **Restuarants**
#
# Importing the yelp Business Data Set and Finding the relevant **City**

# %%
rest = pd.read_json("yelp_academic_dataset_business.json", lines=True)

# %%
rest.loc[0].attributes['GoodForKids']
# Out:
# 'False'

# %% [markdown]
# Looking at the row to identify necessary variables

# %%
rest.loc[1]
# Out:
# business_id                                QXAEGFB4oINsVuTFxEYKFQ
# name                                   Emerald Chinese Restaurant
# address                                      30 Eglinton Avenue W
# city                                                  Mississauga
# state                                                          ON
# postal_code                                               L5R 3E7
# latitude                                                  43.6055
# longitude                                                -79.6523
# stars                                                         2.5
# review_count                                                  128
# is_open                                                         1
# attributes      {'RestaurantsReservations': 'True', 'GoodForMe...
# categories      Specialty Food, Restaurants, Dim Sum, Imported...
# hours           {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...
# Name: 1, dtype: object

# %% [markdown]
# The chosen category **Restaurants** Have about 60000 rows. This is managable but we can drill down to a single city. Hence We will look into the available cities

# %%
len(rest[rest['categories'].str.contains('Restaurants') == True])
# Out:
# 59371

# %% [markdown]
# #### Listing the Cities Available

# %%
list(rest.loc[rest['state'] == 'CA', 'city'].unique())
# Out:
# ['Los Angeles',
#  'Las Vegas',
#  'Monterey Park',
#  'Las Vegas Nv',
#  'Chandler',
#  'San Diego',
#  'Antioch',
#  'Temecula',
#  'Peninsula',
#  'Huntington Beach',
#  'Surprise',
#  'Scottadale',
#  'Nationwide',
#  'Gilbert',
#  'Morgan Hill',
#  'Sacramento',
#  'Dublin']

# %%
rest[rest['city'].str.contains('Diego')]
# Out:
#                   business_id                name  \
# 56948  oBEFhUe7yEH1PK25bImCWA  Brooks Photography
#
#                                 address       city state postal_code  \
# 56948  4372 West Point Loma Blvd, Ste A  San Diego    CA       92107
#
#        latitude   longitude  stars  review_count  is_open  \
# 56948    36.175 -115.136389    1.5            35        1
#
#                                    attributes  \
# 56948  {'BusinessAcceptsCreditCards': 'True'}
#
#                                               categories hours
# 56948  Session Photography, Event Photography, Event ...  None

# %%
rest[rest['city'].str.contains('Angeles')]
# Out:
#                    business_id                          name  \
# 19062   YMeWjOd1svHDGdDCKoiGgg       Electric Daisy Carnival
# 137673  gavl0UJkI0Z5Dzs_tHXQ9A  Rebecca Vinacour Photography
#
#                       address         city state postal_code   latitude  \
# 19062   7000 N Las Vegas Blvd  Los Angeles    CA       90037  36.273260
# 137673                         Los Angeles    CA       90001  33.457453
#
#          longitude  stars  review_count  is_open  \
# 19062  -115.009430    4.5            36        0
# 137673 -112.060988    4.5            11        1
#
#                                                attributes  \
# 19062   {'OutdoorSeating': 'True', 'GoodForKids': 'Fal...
# 137673  {'BusinessAcceptsCreditCards': 'True', 'Busine...
#
#                                                categories hours
# 19062   Local Flavor, Festivals, Arts & Entertainment,...  None
# 137673  Session Photography, Event Planning & Services...  None

# %%
rest[rest['city'].str.contains('Vegas')]
# Out:
#                    business_id                           name  \
# 7       gbQN7vr_caG_A1ugSmGhWg                      Supercuts
# 17      PZ-LZzSlhSe9utkQYU8pFg     Carluccio's Tivoli Gardens
# 18      nh_kQ16QAoXWwqZ05MPfBQ       Myron Hensel Photography
# 20      dFMxzHygTy6F873843dHAA                 Fremont Arcade
# 21      lxnuq9wJiwLOPJ4uZU2ljg            Las Vegas Motorcars
# ...                        ...                            ...
# 192584  XlRGtOjPuiEfZsKuo2fRdw      Costco Hearing Aid Center
# 192586  6tOKoZX1Gj3Uzjc1-JzYNQ  Premier Landscape Maintenance
# 192598  vIAEWbTJc657yN8I4z7whQ                      Starbucks
# 192604  nqb4kWcOwp8bFxzfvaDpZQ             Sanderson Plumbing
# 192608  c1f_VAX1KIK8-JoVhjbYOw                 Oriental Relax
#
#                                      address             city state  \
# 7       4545 E Tropicana Rd Ste 8, Tropicana        Las Vegas    NV
# 17              1775 E Tropicana Ave, Ste 29        Las Vegas    NV
# 18                                                  Las Vegas    NV
# 20                   450 Fremont St, Ste 179        Las Vegas    NV
# 21                       3650 N 5th, Ste 100  North Las Vegas    NV
# ...                                      ...              ...   ...
# 192584                     801 S Pavilion Dr        Las Vegas    NV
# 192586                                              Las Vegas    NV
# 192598         8164 S. Las Vegas Blvd., #100        Las Vegas    NV
# 192604                                        North Las Vegas    NV
# 192608                 3735 S Las Vegas Blvd        Las Vegas    NV
#
#        postal_code   latitude   longitude  stars  review_count  is_open  \
# 7            89121  36.099872 -115.074574    3.5             3        1
# 17           89119  36.100016 -115.128529    4.0            40        0
# 18           89121  36.116549 -115.088115    5.0            21        1
# 20           89101  36.169993 -115.140685    4.5            38        1
# 21           89032  36.225851 -115.132800    3.5             3        1
# ...            ...        ...         ...    ...           ...      ...
# 192584       89101  36.163000 -115.332709    5.0             3        1
# 192586       89107  36.168824 -115.218557    1.0             3        1
# 192598       89123  36.041407 -115.171698    3.0           138        1
# 192604       89032  36.213732 -115.177059    5.0             9        1
# 192608       89109  36.107267 -115.171920    4.0             3        0
#
#                                                attributes  \
# 7       {'RestaurantsPriceRange2': '3', 'GoodForKids':...
# 17      {'OutdoorSeating': 'False', 'BusinessAcceptsCr...
# 18                 {'BusinessAcceptsCreditCards': 'True'}
# 20                                {'GoodForKids': 'True'}
# 21                 {'BusinessAcceptsCreditCards': 'True'}
# ...                                                   ...
# 192584                                               None
# 192586  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 192598  {'OutdoorSeating': 'True', 'WiFi': 'u'free'', ...
# 192604             {'BusinessAcceptsCreditCards': 'True'}
# 192608  {'BikeParking': 'False', 'RestaurantsPriceRang...
#
#                                                categories  \
# 7       Hair Salons, Hair Stylists, Barbers, Men's Hai...
# 17                                   Restaurants, Italian
# 18      Event Planning & Services, Photographers, Prof...
# 20                          Arcades, Arts & Entertainment
# 21                                Automotive, Car Dealers
# ...                                                   ...
# 192584                                               None
# 192586  Landscape Architects, Home Services, Gardeners...
# 192598                                 Food, Coffee & Tea
# 192604  Water Purification Services, Water Heater Inst...
# 192608                             Massage, Beauty & Spas
#
#                                                     hours
# 7       {'Monday': '10:0-19:0', 'Tuesday': '10:0-19:0'...
# 17                                                   None
# 18      {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 20      {'Monday': '11:0-0:0', 'Tuesday': '11:0-0:0', ...
# 21      {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...
# ...                                                   ...
# 192584                                               None
# 192586  {'Monday': '0:0-0:0', 'Tuesday': '7:0-14:0', '...
# 192598  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 192604  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 192608  {'Monday': '10:0-0:0', 'Tuesday': '10:0-0:0', ...
#
# [30992 rows x 14 columns]

# %% [markdown]
# We can see that San Diego and Los Angeles are something relevant but when we explored further, they containes **<10 rows**. Hence we are moving on to 'Las Vegas' that contains about **7000** restaurants
#
# #### We will only focus on these business from now on.
#
# *Storing it into a json file for easy access and loading for the next step

# %%
rest_focus = rest[(rest['categories'].str.contains('Restaurants') == True) & rest['city'].str.contains('Vegas') == True]

# %%
rest_focus.to_json("Yelp Chosen Restaruants.json")

# %% [markdown]
# ## Exploratory Analysis
#
# ### For Reviews
#
# We want only the relevant reviews. Hence we will load the complete data, filter the relevant reviews by comparing the **'business_id'** variable and save that into another excel file:

# %%
rev = pd.read_json("yelp_academic_dataset_review.json", lines = True)

# %%
rev.loc[0]
# Out:
# review_id                                 Q1sbwvVQXV2734tPgoKj4Q
# user_id                                   hG7b0MtEbXx5QzbzE6C_VA
# business_id                               ujmEBvifdJM6h6RLv4wQIg
# stars                                                          1
# useful                                                         6
# funny                                                          1
# cool                                                           0
# text           Total bill for this horrible service? Over $8G...
# date                                         2013-05-07 04:34:36
# Name: 0, dtype: object

# %%
len(rev)
# Out:
# 6685900

# %%
useful_review = pd.merge(rev, rest_focus, on='business_id')

# %%
len(useful_review)
# Out:
# 1269770

# %%
useful_review.loc[0]
# Out:
# review_id                                  kbtscdyz6lvrtGjD1quQTg
# user_id                                    FIk4lQQu1eTe2EpzQ4xhBA
# business_id                                8mIrX_LrOnAqWsB5JrOojQ
# stars_x                                                         4
# useful                                                          0
# funny                                                           0
# cool                                                            0
# text            Like walking back in time, every Saturday morn...
# date                                          2011-11-30 02:11:15
# name                                         Pinball Hall Of Fame
# address                                      1610 E Tropicana Ave
# city                                                    Las Vegas
# state                                                          NV
# postal_code                                                 89119
# latitude                                                  36.1014
# longitude                                                -115.131
# stars_y                                                       4.5
# review_count                                                 1258
# is_open                                                         1
# attributes      {'RestaurantsGoodForGroups': 'True', 'Restaura...
# categories      Performing Arts, Amusement Parks, Museums, Arc...
# hours           {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# Name: 0, dtype: object

# %%
useful_review[useful_review['user_id'] == 'FIk4lQQu1eTe2EpzQ4xhBA']
# Out:
#                       review_id                 user_id  \
# 0        kbtscdyz6lvrtGjD1quQTg  FIk4lQQu1eTe2EpzQ4xhBA
# 37061    63CwPLQFB6azpxnDcdWwzg  FIk4lQQu1eTe2EpzQ4xhBA
# 40422    zVZtAp5z1Nm2XgKoScIM6g  FIk4lQQu1eTe2EpzQ4xhBA
# 40434    -YEhLnvihXC8NvjaGvsxww  FIk4lQQu1eTe2EpzQ4xhBA
# 43167    gY_ZZsmx3k5IF5qXEH-hnQ  FIk4lQQu1eTe2EpzQ4xhBA
# ...                         ...                     ...
# 1262689  E1ARJq-Ln7kTqmdOZFvW2g  FIk4lQQu1eTe2EpzQ4xhBA
# 1266683  4zRNR2Xfz8sbZ6hxiLc40w  FIk4lQQu1eTe2EpzQ4xhBA
# 1266878  1PE_WpQzWdo9uZkdE5SZ3Q  FIk4lQQu1eTe2EpzQ4xhBA
# 1267261  0z-Xe5xL-XgkqePG0iwCxg  FIk4lQQu1eTe2EpzQ4xhBA
# 1268067  aVS7AupIceADC-xTmyjPDw  FIk4lQQu1eTe2EpzQ4xhBA
#
#                     business_id  stars_x  useful  funny  cool  \
# 0        8mIrX_LrOnAqWsB5JrOojQ        4       0      0     0
# 37061    Wxxvi3LZbHNIDwJ-ZimtnA        5       0      0     0
# 40422    tstimHoMcYbkSC4eBA1wEg        4       0      0     0
# 40434    tstimHoMcYbkSC4eBA1wEg        4       1      1     1
# 43167    qG_WEgPa8MBo1dPUOkTMlw        4       0      0     0
# ...                         ...      ...     ...    ...   ...
# 1262689  8fiZjbPMgg4qDSLIdZsWZg        4       2      1     2
# 1266683  lF4pEu4_55SSFEo6Q58ftQ        4       2      1     2
# 1266878  CZJ-s3Io3TQ0Jr2r_tm51g        3       1      0     0
# 1267261  TUpyKJFqL_ySZMo54pT-Sw        4       0      0     0
# 1268067  fnZrZlqW1Z8iWgTVDfv_MA        5       0      0     0
#
#                                                       text  \
# 0        Like walking back in time, every Saturday morn...
# 37061    Love this place, walking into the front desk a...
# 40422    Quiet small place only three tables with patro...
# 40434    Stopped in after a bit of dinner next store, l...
# 43167    I have relatives that talk about in and out as...
# ...                                                    ...
# 1262689  Think bright yellow and orange booths, daisy l...
# 1266683  My husband had been reading about this place f...
# 1266878  This place is now bigger and free standing bui...
# 1267261  Mostly icream and other sweets but they have s...
# 1268067  Great burgers, chicken sandwiches, salads, and...
#
#                        date                                 name  ... state  \
# 0       2011-11-30 02:11:15                 Pinball Hall Of Fame  ...    NV
# 37061   2011-11-29 17:57:46               The Venetian Las Vegas  ...    NV
# 40422   2013-10-31 02:18:37  Maria's Mexican Restaurant & Bakery  ...    NV
# 40434   2013-10-31 02:12:20  Maria's Mexican Restaurant & Bakery  ...    NV
# 43167   2011-11-30 03:13:42                      In-N-Out Burger  ...    NV
# ...                     ...                                  ...  ...   ...
# 1262689 2013-12-30 02:06:10                        Sunshine Cafe  ...    NV
# 1266683 2012-07-13 17:04:44                  German Bread Bakery  ...    NV
# 1266878 2016-01-04 02:06:08            Popeyes Louisiana Kitchen  ...    NV
# 1267261 2013-10-31 02:07:50      La Flor De Michoacan Restaurant  ...    NV
# 1268067 2010-10-18 03:53:22                            Carl's Jr  ...    NV
#
#         postal_code   latitude   longitude  stars_y  review_count  is_open  \
# 0             89119  36.101449 -115.130511      4.5          1258        1
# 37061         89109  36.121189 -115.169657      4.0          3499        1
# 40422         89156  36.195615 -115.040529      4.5           184        1
# 40434         89156  36.195615 -115.040529      4.5           184        1
# 43167         89147  36.100646 -115.302042      4.5           372        1
# ...             ...        ...         ...      ...           ...      ...
# 1262689       89108  36.187877 -115.206286      4.0            39        0
# 1266683       89134  36.202011 -115.282528      4.5           178        1
# 1266878       89146  36.143640 -115.225597      2.5            33        0
# 1267261       89156  36.195615 -115.040529      3.5            52        1
# 1268067       89147  36.099738 -115.301568      2.5            15        0
#
#                                                 attributes  \
# 0        {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 37061    {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 40422    {'BikeParking': 'True', 'BusinessParking': '{'...
# 40434    {'BikeParking': 'True', 'BusinessParking': '{'...
# 43167    {'BusinessParking': '{'garage': False, 'street...
# ...                                                    ...
# 1262689  {'RestaurantsPriceRange2': '1', 'OutdoorSeatin...
# 1266683  {'OutdoorSeating': 'False', 'Caters': 'True', ...
# 1266878  {'BikeParking': 'True', 'BusinessParking': '{'...
# 1267261  {'BikeParking': 'True', 'RestaurantsReservatio...
# 1268067  {'BusinessParking': '{'garage': False, 'street...
#
#                                                 categories  \
# 0        Performing Arts, Amusement Parks, Museums, Arc...
# 37061    Shopping Centers, Resorts, Arts & Entertainmen...
# 40422    Mexican, Restaurants, Patisserie/Cake Shop, Fo...
# 40434    Mexican, Restaurants, Patisserie/Cake Shop, Fo...
# 43167                      Burgers, Fast Food, Restaurants
# ...                                                    ...
# 1262689            Restaurants, Diners, Breakfast & Brunch
# 1266683  Restaurants, Desserts, Pretzels, Food, Bakerie...
# 1266878              Chicken Wings, Fast Food, Restaurants
# 1267261  Juice Bars & Smoothies, American (New), Food, ...
# 1268067                    Restaurants, Fast Food, Mexican
#
#                                                      hours
# 0        {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 37061    {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 40422    {'Monday': '11:0-21:0', 'Tuesday': '10:0-21:0'...
# 40434    {'Monday': '11:0-21:0', 'Tuesday': '10:0-21:0'...
# 43167    {'Monday': '10:30-1:0', 'Tuesday': '10:30-1:0'...
# ...                                                    ...
# 1262689  {'Monday': '7:0-15:0', 'Tuesday': '7:0-15:0', ...
# 1266683  {'Monday': '7:30-16:30', 'Tuesday': '7:30-16:3...
# 1266878  {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...
# 1267261  {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...
# 1268067                                               None
#
# [369 rows x 22 columns]

# %% [markdown]
# #### Shortlisted reviews
#
# When checked on a single user, we found that person has rated 369 restuarants. This is great to train our recommendation engine model. We are saving this subset into another json file

# %%
useful_review.to_json("Yelp Useful Reviews.json")
